# %%
archivo = open('bienvenida.txt', 'w')
archivo.write('Bienvenido a Python\n')
# Out:
# 20

# %%
archivo = open('bienvenida.txt', 'a')
archivo.write('\nHasta pronto')
# Out:
# 13

# %%
archivo = open('bienvenida.txt', 'r')
print(archivo.read())
# Out:
# Hasta pronto

# %%
archivo = open('bienvenida.txt', 'r')
lineas = print(archivo.readlines())
print(lineas)
# Out:
# ['Bienvenido a Python\n', '\n', 'Hasta pronto']
# None

# %%
archivo = open('bienvenida.txt')
print(archivo.read())
archivo.close()
# Out:
# Bienvenido a Python
#
# Hasta pronto

# %%
import os
f = 'bienvenida.txt'

if os.path.isfile(f):
    os.rename(f, 'saludo.txt')
else:
    print('El archivo', f, 'no existe')
    
f = 'saludo.txt'
# Out:
# El archivo bienvenida.txt no existe

# %%
if os.path.isfile(f):
    os.remove(f)
else:
    print('El archivo', f, 'no existe')
    
f
# Out:
# El archivo saludo.txt no existe
# 'saludo.txt'

# %%
from urllib import request
a = request.urlopen('https://mindhubweb.com/')
datos = a.read()
print(datos.decode('utf-8'))
# Out:
# <main class="home">
# <section id="home" class="home__hero">
#       <div class="_slider home__hero__slider">
#                 <div class="home__hero__slide">
#           <div class="home__hero__slide__img"><img src="https://mindhubweb.com/wp-content/uploads/2018/03/WhatsApp-Image-2019-04-05-at-20.15.47-8.jpeg"></div>
#           <div class="home__hero__slide__data home__hero__slide__data--1">
#             <div class="home__hero__slide__quote home__hero__slide__quote--1"><span>We Build Future Skills</span></div>
#           </div>
#         </div>
#                 <div class="home__hero__slide">
#           <div class="home__hero__slide__img"><img src="https://mindhubweb.com/wp-content/uploads/2018/03/WhatsApp-Image-2019-04-05-at-20.15.47-6.jpeg"></div>
#           <div class="home__hero__slide__data home__hero__slide__data--2">
#             <div class="home__hero__slide__quote home__hero__slide__quote--2"><span>Capacitate en MindHub y Empezá a trabajar</span></div>
# ...
